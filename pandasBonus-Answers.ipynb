# %% [markdown]
# # pandas BONUS

# %% [markdown]
# #### If you are using Google Colab, you must run the next line of code. *If you are NOT using Google Colab, do NOT run the next line.*

# %%
# !wget https://raw.githubusercontent.com/aGitHasNoName/dataScienceBasics/main/pigeonRacing.txt

# %% [markdown]
# <br><br>First, we will import pandas and load the pigeon racing dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("pigeonRacing.txt", delimiter="\t")

# %% [markdown]
# <br>Let's take a look at our dataset:

# %%
df.head()
# Out:
#    Position Avg Unirate              Name     Racing Pigeon Color Sex  \
# 0         1       0.26%      Dean Schultz    751 AU 18 PURP    BB   F
# 1         2       1.08%       Dick Fassio    9027 AU 19 SLI  BBAR   F
# 2         3       1.42%       Gary Mosher    32826 AU 17 AA   BKC   F
# 3         4       2.21%  Todd Bartholomew  35624 AU 17 JEDD    BC   F
# 4         5       2.61%   Dustin Maxfield    3322 AU 17 OGN    BB   M
#
#   Qualifying Race Miles  Average Birdage
# 0              469, 469            612.0
# 1              579, 500            139.0
# 2              494, 539            103.0
# 3              547, 468            226.0
# 4              462, 462            171.0

# %% [markdown]
# ## <br><br>Working with Missing Data

# %% [markdown]
# <br>Let's look at a larger sample of our dataset:

# %%
df.sample(10)
# Out:
#     Position Avg Unirate               Name    Racing Pigeon Color Sex  \
# 4          5       2.61%    Dustin Maxfield   3322 AU 17 OGN    BB   M
# 31        32       9.67%   Todd Bartholomew   7005 AU 19 OGN    BC   F
# 2          3       1.42%        Gary Mosher   32826 AU 17 AA   BKC   F
# 29        30       9.53%         Rick Cline    9041 AU 19 MM   DCP   M
# 21        22       7.13%         Terry Lynn      8 AU 16 GCM    BB   F
# 8          9       3.31%  Rodney Desrosiers    1608 AU 17 SC   NaN   F
# 27        28       8.89%     Larry Mitchell  1955 AU 19 HOTR    BB   M
# 33        34       9.86%        Dave Tracey     34 AU 18 PCO    BB   M
# 22        23       8.01%        Gary Mosher   32882 AU 17 AA   BLS   M
# 23        24       8.07%        Alven Gines   9833 AU 19 SLI  BBAR   F
#
#    Qualifying Race Miles  Average Birdage
# 4               462, 462            171.0
# 31              468, 469            139.0
# 2               494, 539            103.0
# 29              466, 541             42.0
# 21              513, 518             49.0
# 8               563, 459             46.0
# 27              584, 505            123.0
# 33              537, 535             72.0
# 22              539, 494            103.0
# 23              584, 505            123.0

# %% [markdown]
# <br>Missing values are represented as a special pandas object: **`NaN`**. It stands for Not a Number. The NaN value will let you complete numerical calculations on your data - it will ignore the value, so it will not include the value in calculations.

# %%
df["Average Birdage"].mean()
# Out:
# 149.79310344827587

# %% [markdown]
# ### <br><br>Finding missing data

# %% [markdown]
# We can look for missing data in our DataFrame using `isnull()`.

# %%
df.isnull()
# Out:
#     Position  Avg Unirate   Name  Racing Pigeon  Color    Sex  \
# 0      False        False  False          False  False  False
# 1      False        False  False          False  False  False
# 2      False        False  False          False  False  False
# 3      False        False  False          False  False  False
# 4      False        False  False          False  False  False
# 5      False        False  False          False   True  False
# 6      False        False  False          False  False  False
# 7      False        False  False          False  False  False
# 8      False        False  False          False   True  False
# 9      False        False  False          False  False  False
# 10     False        False  False          False  False  False
# 11     False        False  False          False  False  False
# 12     False        False  False          False   True  False
# 13     False        False  False          False  False  False
# 14     False        False  False          False  False  False
# 15     False        False  False          False  False  False
# 16     False        False  False          False  False  False
# 17     False        False  False          False  False  False
# 18     False        False  False          False  False  False
# 19     False        False  False          False   True  False
# 20     False        False  False          False   True  False
# 21     False        False  False          False  False  False
# 22     False        False  False          False  False  False
# 23     False        False  False          False  False  False
# 24     False        False  False          False  False  False
# 25     False        False  False          False  False  False
# 26     False        False  False          False   True  False
# 27     False        False  False          False  False  False
# 28     False        False  False          False   True  False
# 29     False        False  False          False  False  False
# 30     False        False  False          False  False  False
# 31     False        False  False          False  False  False
# 32     False        False  False          False  False  False
# 33     False        False  False          False  False  False
#
#     Qualifying Race Miles  Average Birdage
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# 5                   False            False
# 6                   False             True
# 7                   False            False
# 8                   False            False
# 9                   False            False
# 10                  False            False
# 11                  False            False
# 12                  False            False
# 13                  False            False
# 14                  False            False
# 15                  False            False
# 16                  False            False
# 17                  False            False
# 18                  False             True
# 19                  False            False
# 20                  False             True
# 21                  False            False
# 22                  False            False
# 23                  False            False
# 24                  False            False
# 25                  False            False
# 26                  False            False
# 27                  False            False
# 28                  False             True
# 29                  False            False
# 30                  False            False
# 31                  False            False
# 32                  False             True
# 33                  False            False

# %% [markdown]
# <br><br>We can do the opposite - look for all values that aren't missing - using `notnull()`.

# %%
df.notnull()
# Out:
#     Position  Avg Unirate  Name  Racing Pigeon  Color   Sex  \
# 0       True         True  True           True   True  True
# 1       True         True  True           True   True  True
# 2       True         True  True           True   True  True
# 3       True         True  True           True   True  True
# 4       True         True  True           True   True  True
# 5       True         True  True           True  False  True
# 6       True         True  True           True   True  True
# 7       True         True  True           True   True  True
# 8       True         True  True           True  False  True
# 9       True         True  True           True   True  True
# 10      True         True  True           True   True  True
# 11      True         True  True           True   True  True
# 12      True         True  True           True  False  True
# 13      True         True  True           True   True  True
# 14      True         True  True           True   True  True
# 15      True         True  True           True   True  True
# 16      True         True  True           True   True  True
# 17      True         True  True           True   True  True
# 18      True         True  True           True   True  True
# 19      True         True  True           True  False  True
# 20      True         True  True           True  False  True
# 21      True         True  True           True   True  True
# 22      True         True  True           True   True  True
# 23      True         True  True           True   True  True
# 24      True         True  True           True   True  True
# 25      True         True  True           True   True  True
# 26      True         True  True           True  False  True
# 27      True         True  True           True   True  True
# 28      True         True  True           True  False  True
# 29      True         True  True           True   True  True
# 30      True         True  True           True   True  True
# 31      True         True  True           True   True  True
# 32      True         True  True           True   True  True
# 33      True         True  True           True   True  True
#
#     Qualifying Race Miles  Average Birdage
# 0                    True             True
# 1                    True             True
# 2                    True             True
# 3                    True             True
# 4                    True             True
# 5                    True             True
# 6                    True            False
# 7                    True             True
# 8                    True             True
# 9                    True             True
# 10                   True             True
# 11                   True             True
# 12                   True             True
# 13                   True             True
# 14                   True             True
# 15                   True             True
# 16                   True             True
# 17                   True             True
# 18                   True            False
# 19                   True             True
# 20                   True            False
# 21                   True             True
# 22                   True             True
# 23                   True             True
# 24                   True             True
# 25                   True             True
# 26                   True             True
# 27                   True             True
# 28                   True            False
# 29                   True             True
# 30                   True             True
# 31                   True             True
# 32                   True            False
# 33                   True             True

# %% [markdown]
# <br><br>This would be hard to sort through in a big DataFrame, so we can add the `nunique()` aggregation function to see which columns have missing data:

# %%
df.isnull().nunique()
# Out:
# Position                 1
# Avg Unirate              1
# Name                     1
# Racing Pigeon            1
# Color                    2
# Sex                      1
# Qualifying Race Miles    1
# Average Birdage          2
# dtype: int64

# %% [markdown]
# <br>Or we could check a particular column of interest:

# %%
df["Color"].isnull().nunique()
# Out:
# 2

# %% [markdown]
# <br>Another way to look for missing data is to get a count of each column:

# %%
df.count()
# Out:
# Position                 34
# Avg Unirate              34
# Name                     34
# Racing Pigeon            34
# Color                    27
# Sex                      34
# Qualifying Race Miles    34
# Average Birdage          29
# dtype: int64

# %% [markdown]
# <br><br>We have two columns with missing data - one is numerical data (Average Birdage) and one is categorial (Color).
# <br><br>We're going to walk through a few common ways to deal with missing data.
# <br><br>First, let's check the number of rows and columns in our original DataFrame to compare later:

# %%
df.shape
# Out:
# (34, 8)

# %% [markdown]
# ### <br><br>Drop all rows with NaN

# %% [markdown]
# Let's drop every row with any NaN value using the `dropna()` function.

# %%
df_no_nan_rows = df.dropna()
df_no_nan_rows.shape
# Out:
# (24, 8)

# %% [markdown]
# ### <br><br>Drop all columns with NaN

# %% [markdown]
# Same function, but we add the keyword argument for columns:

# %%
df_no_nan_columns = df.dropna(axis=1)
df_no_nan_columns.shape
# Out:
# (34, 6)

# %% [markdown]
# ### <br><br>Drop rows with NaN in a particular column

# %% [markdown]
# At first, you might try to use the regular `drop()` function with a boolean, but this won't work:

# %%
df_drop_rows_nan_color = df.drop(df["Color"].isnull())
df_drop_rows_nan_color.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_drop_rows_nan_color = df.drop(df["Color"].isnull())
#       2 df_drop_rows_nan_color.shape
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, True, False, False, False, False, False] not found in axis'

# %% [markdown]
# <br>Instead, we can create a subset of the DataFrame that includes only rows that are not null in the Color column. We are using the pandas function `notnull()` to return any non-NaN values. Instead of adding the function to the end of the DataFrame or the end of the column, we use the function on its own with the `pd.notnull()` syntax. We pass the function the piece of the DataFrame that we want it to search through.

# %%
df_drop_rows_nan_color = df[pd.notnull(df["Color"])]
df_drop_rows_nan_color.shape
# Out:
# (27, 8)

# %% [markdown]
# ### <br><br>Replace all NaNs with zero

# %% [markdown]
# Pandas has a `fillna()` function that will work over the entire DataFrame:

# %%
df_fill_zeros = df.fillna(0)
df_fill_zeros.shape
# Out:
# (34, 8)

# %%
df_fill_zeros.sample(10)
# Out:
#     Position Avg Unirate                Name     Racing Pigeon Color Sex  \
# 16        17       5.88%          Kevin Coey    349 AU 17 BUCK  BLCH   F
# 3          4       2.21%    Todd Bartholomew  35624 AU 17 JEDD    BC   F
# 12        13       4.68%  Dennis Heidenreich    1127 AU 18 UVI     0   F
# 0          1       0.26%        Dean Schultz    751 AU 18 PURP    BB   F
# 24        25       8.11%  Lek Dhiraprasiddhi    161 AU 15 BUCK  DCWF   F
# 13        14       4.70%         Butch Smith      313 AU 18 ER   BLK   F
# 18        19       6.47%       Thomas Erdner  12011 AU 19 FOYS    BB   F
# 14        15       4.76%        Gordon Smith   4592 AU 19 SMIT  BCHK   F
# 21        22       7.13%          Terry Lynn       8 AU 16 GCM    BB   F
# 17        18       6.07%       Joe Bevington    15377 AU 19 AA    DC   F
#
#    Qualifying Race Miles  Average Birdage
# 16              536, 540             72.0
# 3               547, 468            226.0
# 12              594, 515             85.0
# 0               469, 469            612.0
# 24              520, 506             49.0
# 13              505, 593             32.0
# 18              553, 470              0.0
# 14              516, 595             91.0
# 21              513, 518             49.0
# 17              488, 572            353.0

# %% [markdown]
# <br>This replaced NaNs in both the Colors and Average Birdage columns with 0. That might not be what you want to do.

# %% [markdown]
# ### <br><br>Replace NaNs in only one column with the mean value of that column.

# %% [markdown]
# This one is tricky. I don't expect you to remember how to do this. As with many things in Pandas, it isn't always intuitive how to solve every unique situation. Pandas users rely on looking things up online, and that is what I did to solve this one.

# %% [markdown]
# <br>First, we need to make a copy of the original DataFrame because we are going to reference the new version on the left side of our assignment operator. If we don't do this, we would have to change the original df.
# <br><br>Then I am going to reassign the Average Birdage column to the same column, but with the `fillna()` function applied. I am going to fill the NaNs with the mean value of that column.

# %%
df_mean_birdage = df.copy()
df_mean_birdage["Average Birdage"] = df_mean_birdage["Average Birdage"].fillna(df["Average Birdage"].mean())
df_mean_birdage.sample(10)
# Out:
#     Position Avg Unirate              Name     Racing Pigeon Color Sex  \
# 27        28       8.89%    Larry Mitchell   1955 AU 19 HOTR    BB   M
# 20        21       6.81%   Dustin Maxfield    7800 AU 19 OGN   NaN   F
# 18        19       6.47%     Thomas Erdner  12011 AU 19 FOYS    BB   F
# 19        20       6.78%    Keith Delpozzo     913 AU 16 SRI   NaN   M
# 0          1       0.26%      Dean Schultz    751 AU 18 PURP    BB   F
# 23        24       8.07%       Alven Gines    9833 AU 19 SLI  BBAR   F
# 32        33       9.69%    Curt Templeton    784 AU 17 POLK  BBAR   F
# 4          5       2.61%   Dustin Maxfield    3322 AU 17 OGN    BB   M
# 31        32       9.67%  Todd Bartholomew    7005 AU 19 OGN    BC   F
# 2          3       1.42%       Gary Mosher    32826 AU 17 AA   BKC   F
#
#    Qualifying Race Miles  Average Birdage
# 27              584, 505       123.000000
# 20              541, 462       149.793103
# 18              553, 470       149.793103
# 19              466, 567        31.000000
# 0               469, 469       612.000000
# 23              584, 505       123.000000
# 32              462, 462       149.793103
# 4               462, 462       171.000000
# 31              468, 469       139.000000
# 2               494, 539       103.000000

# %% [markdown]
# ### <br><br>Exercise 1

# %% [markdown]
# Write code to replace any missing data in the `Color` column with the string "BB". I've started for you by making a copy of the DataFrame.

# %%
df_replace_colors = df.copy()

# %%
df_replace_colors["Color"] = df_replace_colors["Color"].fillna("BB")

# %%
df_replace_colors.sample(10)
# Out:
#     Position Avg Unirate             Name     Racing Pigeon Color Sex  \
# 9         10       3.44%      Dave Tracey     324 AU 17 GCM  BECA   F
# 10        11       3.69%      Gary Mosher    47663 AU 17 AA   BLS   M
# 18        19       6.47%    Thomas Erdner  12011 AU 19 FOYS    BB   F
# 7          8       3.27%     Dean Schultz   1707 AU 17 SCHU    BC   F
# 17        18       6.07%    Joe Bevington    15377 AU 19 AA    DC   F
# 1          2       1.08%      Dick Fassio    9027 AU 19 SLI  BBAR   F
# 13        14       4.70%      Butch Smith      313 AU 18 ER   BLK   F
# 26        27       8.81%      Edward King  77692 AU 16 ARPU    BB   M
# 30        31       9.65%    Joe Bevington  25221 AU 18 ARPU    BC   F
# 4          5       2.61%  Dustin Maxfield    3322 AU 17 OGN    BB   M
#
#    Qualifying Race Miles  Average Birdage
# 9               535, 537             72.0
# 10              539, 494            103.0
# 18              553, 470              NaN
# 7               469, 469            526.0
# 17              488, 572            353.0
# 1               579, 500            139.0
# 13              505, 593             32.0
# 26              632, 538             76.0
# 30              488, 572            353.0
# 4               462, 462            171.0

# %% [markdown]
# ## <br><br>Data types

# %% [markdown]
# Let's reload the WNBA game data.

# %% [markdown]
# #### If you are using Google Colab, you must run the next line of code. *If you are NOT using Google Colab, do NOT run the next line.*

# %%
# !wget https://raw.githubusercontent.com/aGitHasNoName/pandasBasics/main/wnba-team-elo-ratings.csv

# %% [markdown]
# <br><br>Our sample dataset was taken from FiveThirtyEight. It contains game data for WNBA games since 1997.

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv")

# %%
df.head()
# Out:
#    season        date team1 team2               name1               name2  \
# 0    2019  10/10/2019   WAS   CON  Washington Mystics     Connecticut Sun
# 1    2019  10/10/2019   CON   WAS     Connecticut Sun  Washington Mystics
# 2    2019   10/8/2019   WAS   CON  Washington Mystics     Connecticut Sun
# 3    2019   10/8/2019   CON   WAS     Connecticut Sun  Washington Mystics
# 4    2019   10/6/2019   WAS   CON  Washington Mystics     Connecticut Sun
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 0        0        1      89      78      1684      1634       1692       1627
# 1        0        1      78      89      1634      1684       1627       1692
# 2        0        1      86      90      1693      1626       1684       1634
# 3        0        1      90      86      1626      1693       1634       1684
# 4        0        1      94      81      1671      1648       1693       1626
#
#    prob1  is_home1
# 0  0.718         1
# 1  0.282         0
# 2  0.476         0
# 3  0.524         1
# 4  0.399         0

# %% [markdown]
# <br><br>We can check the data type of all columns using the `dtypes` attribute.

# %%
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre       int64
# elo2_pre       int64
# elo1_post      int64
# elo2_post      int64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# <br>An `object` is a string or a column with mixed datatypes.

# %% [markdown]
# We can change the data type of a column using the method function `astype()`. Let's change the elo ratings from integers to floats. We can only change one column at a time. Since we only want the change applied to one column, we have to only include that column on the left side of our assignment:

# %%
df["elo1_pre"] = df["elo1_pre"].astype("float")
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre       int64
# elo1_post      int64
# elo2_post      int64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# <br>To change all the elo columns, we could write a loop:

# %%
for i in ["elo2_pre", "elo1_post", "elo2_post"]:
    df[i] = df[i].astype("float")
df.dtypes
# Out:
# season         int64
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre     float64
# elo1_post    float64
# elo2_post    float64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# ### <br><br>Exercise 2

# %% [markdown]
# Write code to change the `season` column from an integer to an `object`:

# %%
df["season"] = df["season"].astype("object")

# %%
df.dtypes
# Out:
# season        object
# date          object
# team1         object
# team2         object
# name1         object
# name2         object
# neutral        int64
# playoff        int64
# score1         int64
# score2         int64
# elo1_pre     float64
# elo2_pre     float64
# elo1_post    float64
# elo2_post    float64
# prob1        float64
# is_home1       int64
# dtype: object

# %% [markdown]
# Write code to change the playoff column from an integer to a boolean (try `bool`):

# %%
df["playoff"] = df["playoff"].astype("bool")

# %%
df.sample(5)
# Out:
#       season       date team1 team2                     name1  \
# 2594    2014  5/30/2014   MIN   LVA            Minnesota Lynx
# 7487    2003  8/16/2003   PHO   SAC           Phoenix Mercury
# 1359    2016  9/18/2016   LVA   PHO  San Antonio Silver Stars
# 10145   1998   7/8/1998   DAL   PHO             Detroit Shock
# 2447    2014   7/5/2014   WAS   ATL        Washington Mystics
#
#                           name2  neutral  playoff  score1  score2  elo1_pre  \
# 2594   San Antonio Silver Stars        0    False      88      72    1643.0
# 7487        Sacramento Monarchs        0    False      61      65    1377.0
# 1359            Phoenix Mercury        0    False      65      81    1316.0
# 10145           Phoenix Mercury        0    False      76      78    1400.0
# 2447              Atlanta Dream        0    False      73      86    1446.0
#
#        elo2_pre  elo1_post  elo2_post  prob1  is_home1
# 2594     1471.0     1650.0     1465.0  0.810         1
# 7487     1558.0     1372.0     1564.0  0.359         1
# 1359     1527.0     1304.0     1538.0  0.320         1
# 10145    1563.0     1395.0     1568.0  0.382         1
# 2447     1551.0     1438.0     1558.0  0.257         0

# %% [markdown]
# <br><br><br>A `datetime` is a special Python data type. To convert a column to a datetime object, you use a different function, `to_datetime`.

# %%
df["date"] = pd.to_datetime(df["date"])
df.sample(5)
# Out:
#      season       date team1 team2               name1            name2  \
# 1225   2017 2017-06-09   LAS   DAL  Los Angeles Sparks     Dallas Wings
# 591    2018 2018-07-22   LVA   IND      Las Vegas Aces    Indiana Fever
# 2389   2014 2014-07-17   CON   PHO     Connecticut Sun  Phoenix Mercury
# 1763   2015 2015-10-11   MIN   IND      Minnesota Lynx    Indiana Fever
# 5423   2008 2008-05-17   SEA   CHI       Seattle Storm      Chicago Sky
#
#       neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# 1225        0    False      90      96    1598.0    1436.0     1583.0
# 591         0    False      88      74    1498.0    1326.0     1503.0
# 2389        0    False      85     101    1447.0    1660.0     1442.0
# 1763        0     True      69      75    1576.0    1597.0     1570.0
# 5423        0    False      67      61    1495.0    1468.0     1502.0
#
#       elo2_post  prob1  is_home1
# 1225     1450.0  0.615         0
# 591      1320.0  0.810         1
# 2389     1665.0  0.157         0
# 1763     1603.0  0.326         0
# 5423     1461.0  0.649         1

# %%
df.dtypes
# Out:
# season               object
# date         datetime64[ns]
# team1                object
# team2                object
# name1                object
# name2                object
# neutral               int64
# playoff                bool
# score1                int64
# score2                int64
# elo1_pre            float64
# elo2_pre            float64
# elo1_post           float64
# elo2_post           float64
# prob1               float64
# is_home1              int64
# dtype: object

# %% [markdown]
# <br>The format shown is YYYY-MM-DD. If a time is provided, it will also be converted.
# <br><br>Once a column is converted to a datetime object, you can sample that column based on several date formats:

# %%
df.loc[df["date"] == "10-6-2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %%
df.loc[df["date"] == "10/6/19", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %%
df.loc[df["date"] == "Oct 6 2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 4   2019 2019-10-06   WAS   CON  Washington Mystics     Connecticut Sun
# 5   2019 2019-10-06   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 4        0     True      94      81    1671.0    1648.0     1693.0     1626.0
# 5        0     True      81      94    1648.0    1671.0     1626.0     1693.0
#
#    prob1  is_home1
# 4  0.399         0
# 5  0.601         1

# %% [markdown]
# <br><br>You can also use other operators with datetime objects:

# %%
df.loc[df["date"] > "Oct 6 2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 0   2019 2019-10-10   WAS   CON  Washington Mystics     Connecticut Sun
# 1   2019 2019-10-10   CON   WAS     Connecticut Sun  Washington Mystics
# 2   2019 2019-10-08   WAS   CON  Washington Mystics     Connecticut Sun
# 3   2019 2019-10-08   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 0        0     True      89      78    1684.0    1634.0     1692.0     1627.0
# 1        0     True      78      89    1634.0    1684.0     1627.0     1692.0
# 2        0     True      86      90    1693.0    1626.0     1684.0     1634.0
# 3        0     True      90      86    1626.0    1693.0     1634.0     1684.0
#
#    prob1  is_home1
# 0  0.718         1
# 1  0.282         0
# 2  0.476         0
# 3  0.524         1

# %% [markdown]
# ### <br><br>Exercise 3

# %% [markdown]
# Pick a random day between 2012 and 2019 and see if any games were played that day. Games are usually played between late May and mid October. If you can't find a game on the day you picked, try a different day until you find a game.

# %%
df.loc[df["date"] == "10/01/2019", :]
# Out:
#   season       date team1 team2               name1               name2  \
# 6   2019 2019-10-01   WAS   CON  Washington Mystics     Connecticut Sun
# 7   2019 2019-10-01   CON   WAS     Connecticut Sun  Washington Mystics
#
#    neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  elo2_post  \
# 6        0     True      87      99    1700.0    1618.0     1671.0     1648.0
# 7        0     True      99      87    1618.0    1700.0     1648.0     1671.0
#
#    prob1  is_home1
# 6  0.763         1
# 7  0.237         0

# %% [markdown]
# <br>Write a multiple conditional to find games played between July 7, 2012 and September 7, 2012.

# %%
df.loc[(df["date"] >= "07/07/2012") & (df["date"] <= "09/07/2012"), :]
# Out:
#      season       date team1 team2                     name1  \
# 3212   2012 2012-09-07   MIN   ATL            Minnesota Lynx
# 3213   2012 2012-09-07   IND   LVA             Indiana Fever
# 3214   2012 2012-09-07   LVA   IND  San Antonio Silver Stars
# 3215   2012 2012-09-07   LAS   WAS        Los Angeles Sparks
# 3216   2012 2012-09-07   CON   PHO           Connecticut Sun
# ...     ...        ...   ...   ...                       ...
# 3357   2012 2012-07-07   ATL   PHO             Atlanta Dream
# 3358   2012 2012-07-07   LAS   SEA        Los Angeles Sparks
# 3359   2012 2012-07-07   SEA   LAS             Seattle Storm
# 3360   2012 2012-07-07   CHI   IND               Chicago Sky
# 3361   2012 2012-07-07   PHO   ATL           Phoenix Mercury
#
#                          name2  neutral  playoff  score1  score2  elo1_pre  \
# 3212             Atlanta Dream        0    False      97      93    1706.0
# 3213  San Antonio Silver Stars        0    False      82      78    1588.0
# 3214             Indiana Fever        0    False      78      82    1591.0
# 3215        Washington Mystics        0    False      96      68    1559.0
# 3216           Phoenix Mercury        0    False      82      91    1584.0
# ...                        ...      ...      ...     ...     ...       ...
# 3357           Phoenix Mercury        0    False     100      93    1542.0
# 3358             Seattle Storm        0    False      83      59    1483.0
# 3359        Los Angeles Sparks        0    False      59      83    1512.0
# 3360             Indiana Fever        0    False      86      88    1490.0
# 3361             Atlanta Dream        0    False      93     100    1401.0
#
#       elo2_pre  elo1_post  elo2_post  prob1  is_home1
# 3212    1554.0     1709.0     1551.0  0.792         1
# 3213    1591.0     1600.0     1579.0  0.383         0
# 3214    1588.0     1579.0     1600.0  0.617         1
# 3215    1332.0     1574.0     1316.0  0.699         0
# 3216    1332.0     1552.0     1364.0  0.871         1
# ...        ...        ...        ...    ...       ...
# 3357    1401.0     1552.0     1392.0  0.588         0
# 3358    1512.0     1505.0     1491.0  0.573         1
# 3359    1483.0     1491.0     1505.0  0.427         0
# 3360    1553.0     1486.0     1557.0  0.305         0
# 3361    1542.0     1392.0     1552.0  0.412         1
#
# [150 rows x 16 columns]

# %%
df.loc[df["date"].between("07/07/2012", "09/07/2012"), :]
# Out:
#      season       date team1 team2                     name1  \
# 3212   2012 2012-09-07   MIN   ATL            Minnesota Lynx
# 3213   2012 2012-09-07   IND   LVA             Indiana Fever
# 3214   2012 2012-09-07   LVA   IND  San Antonio Silver Stars
# 3215   2012 2012-09-07   LAS   WAS        Los Angeles Sparks
# 3216   2012 2012-09-07   CON   PHO           Connecticut Sun
# ...     ...        ...   ...   ...                       ...
# 3357   2012 2012-07-07   ATL   PHO             Atlanta Dream
# 3358   2012 2012-07-07   LAS   SEA        Los Angeles Sparks
# 3359   2012 2012-07-07   SEA   LAS             Seattle Storm
# 3360   2012 2012-07-07   CHI   IND               Chicago Sky
# 3361   2012 2012-07-07   PHO   ATL           Phoenix Mercury
#
#                          name2  neutral  playoff  score1  score2  elo1_pre  \
# 3212             Atlanta Dream        0    False      97      93    1706.0
# 3213  San Antonio Silver Stars        0    False      82      78    1588.0
# 3214             Indiana Fever        0    False      78      82    1591.0
# 3215        Washington Mystics        0    False      96      68    1559.0
# 3216           Phoenix Mercury        0    False      82      91    1584.0
# ...                        ...      ...      ...     ...     ...       ...
# 3357           Phoenix Mercury        0    False     100      93    1542.0
# 3358             Seattle Storm        0    False      83      59    1483.0
# 3359        Los Angeles Sparks        0    False      59      83    1512.0
# 3360             Indiana Fever        0    False      86      88    1490.0
# 3361             Atlanta Dream        0    False      93     100    1401.0
#
#       elo2_pre  elo1_post  elo2_post  prob1  is_home1
# 3212    1554.0     1709.0     1551.0  0.792         1
# 3213    1591.0     1600.0     1579.0  0.383         0
# 3214    1588.0     1579.0     1600.0  0.617         1
# 3215    1332.0     1574.0     1316.0  0.699         0
# 3216    1332.0     1552.0     1364.0  0.871         1
# ...        ...        ...        ...    ...       ...
# 3357    1401.0     1552.0     1392.0  0.588         0
# 3358    1512.0     1505.0     1491.0  0.573         1
# 3359    1483.0     1491.0     1505.0  0.427         0
# 3360    1553.0     1486.0     1557.0  0.305         0
# 3361    1542.0     1392.0     1552.0  0.412         1
#
# [150 rows x 16 columns]

# %% [markdown]
# <br><br><br>We can set a column from our DataFrame as the index using set_index(), but if there are duplicates in the column, it won't be that useful.

# %%
df.set_index("team1")
# Out:
#       season       date team2                name1                name2  \
# team1
# WAS     2019 2019-10-10   CON   Washington Mystics      Connecticut Sun
# CON     2019 2019-10-10   WAS      Connecticut Sun   Washington Mystics
# WAS     2019 2019-10-08   CON   Washington Mystics      Connecticut Sun
# CON     2019 2019-10-08   WAS      Connecticut Sun   Washington Mystics
# WAS     2019 2019-10-06   CON   Washington Mystics      Connecticut Sun
# ...      ...        ...   ...                  ...                  ...
# SAC     1997 1997-06-21   LVA  Sacramento Monarchs          Utah Starzz
# NYL     1997 1997-06-21   LAS     New York Liberty   Los Angeles Sparks
# LAS     1997 1997-06-21   NYL   Los Angeles Sparks     New York Liberty
# LVA     1997 1997-06-21   SAC          Utah Starzz  Sacramento Monarchs
# CLE     1997 1997-06-21   HOU    Cleveland Rockers       Houston Comets
#
#        neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# team1
# WAS          0     True      89      78    1684.0    1634.0     1692.0
# CON          0     True      78      89    1634.0    1684.0     1627.0
# WAS          0     True      86      90    1693.0    1626.0     1684.0
# CON          0     True      90      86    1626.0    1693.0     1634.0
# WAS          0     True      94      81    1671.0    1648.0     1693.0
# ...        ...      ...     ...     ...       ...       ...        ...
# SAC          0    False      73      61    1500.0    1500.0     1521.0
# NYL          0    False      67      57    1500.0    1500.0     1519.0
# LAS          0    False      57      67    1500.0    1500.0     1481.0
# LVA          0    False      61      73    1500.0    1500.0     1479.0
# CLE          0    False      56      76    1500.0    1500.0     1470.0
#
#        elo2_post  prob1  is_home1
# team1
# WAS       1627.0  0.718         1
# CON       1692.0  0.282         0
# WAS       1634.0  0.476         0
# CON       1684.0  0.524         1
# WAS       1626.0  0.399         0
# ...          ...    ...       ...
# SAC       1479.0  0.387         0
# NYL       1481.0  0.387         0
# LAS       1519.0  0.613         1
# LVA       1521.0  0.613         1
# CLE       1530.0  0.613         1
#
# [10488 rows x 15 columns]

# %%
df.set_index("date")
# Out:
#            season team1 team2                name1                name2  \
# date
# 2019-10-10   2019   WAS   CON   Washington Mystics      Connecticut Sun
# 2019-10-10   2019   CON   WAS      Connecticut Sun   Washington Mystics
# 2019-10-08   2019   WAS   CON   Washington Mystics      Connecticut Sun
# 2019-10-08   2019   CON   WAS      Connecticut Sun   Washington Mystics
# 2019-10-06   2019   WAS   CON   Washington Mystics      Connecticut Sun
# ...           ...   ...   ...                  ...                  ...
# 1997-06-21   1997   SAC   LVA  Sacramento Monarchs          Utah Starzz
# 1997-06-21   1997   NYL   LAS     New York Liberty   Los Angeles Sparks
# 1997-06-21   1997   LAS   NYL   Los Angeles Sparks     New York Liberty
# 1997-06-21   1997   LVA   SAC          Utah Starzz  Sacramento Monarchs
# 1997-06-21   1997   CLE   HOU    Cleveland Rockers       Houston Comets
#
#             neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# date
# 2019-10-10        0     True      89      78    1684.0    1634.0     1692.0
# 2019-10-10        0     True      78      89    1634.0    1684.0     1627.0
# 2019-10-08        0     True      86      90    1693.0    1626.0     1684.0
# 2019-10-08        0     True      90      86    1626.0    1693.0     1634.0
# 2019-10-06        0     True      94      81    1671.0    1648.0     1693.0
# ...             ...      ...     ...     ...       ...       ...        ...
# 1997-06-21        0    False      73      61    1500.0    1500.0     1521.0
# 1997-06-21        0    False      67      57    1500.0    1500.0     1519.0
# 1997-06-21        0    False      57      67    1500.0    1500.0     1481.0
# 1997-06-21        0    False      61      73    1500.0    1500.0     1479.0
# 1997-06-21        0    False      56      76    1500.0    1500.0     1470.0
#
#             elo2_post  prob1  is_home1
# date
# 2019-10-10     1627.0  0.718         1
# 2019-10-10     1692.0  0.282         0
# 2019-10-08     1634.0  0.476         0
# 2019-10-08     1684.0  0.524         1
# 2019-10-06     1626.0  0.399         0
# ...               ...    ...       ...
# 1997-06-21     1479.0  0.387         0
# 1997-06-21     1481.0  0.387         0
# 1997-06-21     1519.0  0.613         1
# 1997-06-21     1521.0  0.613         1
# 1997-06-21     1530.0  0.613         1
#
# [10488 rows x 15 columns]

# %% [markdown]
# ### <br><br><br>Cleaning data while loading

# %% [markdown]
# Several of the data cleaning tasks we've learned can be done when loading the file in as a pandas DataFrame.

# %% [markdown]
# **Telling pandas to make a particular column the index while loading:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date")
df.head()
# Out:
#             season team1 team2               name1               name2  \
# date
# 10/10/2019    2019   WAS   CON  Washington Mystics     Connecticut Sun
# 10/10/2019    2019   CON   WAS     Connecticut Sun  Washington Mystics
# 10/8/2019     2019   WAS   CON  Washington Mystics     Connecticut Sun
# 10/8/2019     2019   CON   WAS     Connecticut Sun  Washington Mystics
# 10/6/2019     2019   WAS   CON  Washington Mystics     Connecticut Sun
#
#             neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# date
# 10/10/2019        0        1      89      78      1684      1634       1692
# 10/10/2019        0        1      78      89      1634      1684       1627
# 10/8/2019         0        1      86      90      1693      1626       1684
# 10/8/2019         0        1      90      86      1626      1693       1634
# 10/6/2019         0        1      94      81      1671      1648       1693
#
#             elo2_post  prob1  is_home1
# date
# 10/10/2019       1627  0.718         1
# 10/10/2019       1692  0.282         0
# 10/8/2019        1634  0.476         0
# 10/8/2019        1684  0.524         1
# 10/6/2019        1626  0.399         0

# %% [markdown]
# **<br>Telling pandas to make your date column the index and convert it to a datetime object when loading:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date", parse_dates=True)
df.head()
# Out:
#             season team1 team2               name1               name2  \
# date
# 2019-10-10    2019   WAS   CON  Washington Mystics     Connecticut Sun
# 2019-10-10    2019   CON   WAS     Connecticut Sun  Washington Mystics
# 2019-10-08    2019   WAS   CON  Washington Mystics     Connecticut Sun
# 2019-10-08    2019   CON   WAS     Connecticut Sun  Washington Mystics
# 2019-10-06    2019   WAS   CON  Washington Mystics     Connecticut Sun
#
#             neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# date
# 2019-10-10        0        1      89      78      1684      1634       1692
# 2019-10-10        0        1      78      89      1634      1684       1627
# 2019-10-08        0        1      86      90      1693      1626       1684
# 2019-10-08        0        1      90      86      1626      1693       1634
# 2019-10-06        0        1      94      81      1671      1648       1693
#
#             elo2_post  prob1  is_home1
# date
# 2019-10-10       1627  0.718         1
# 2019-10-10       1692  0.282         0
# 2019-10-08       1634  0.476         0
# 2019-10-08       1684  0.524         1
# 2019-10-06       1626  0.399         0

# %% [markdown]
# **<br>Telling pandas to only load some columns:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", usecols=["season", "team1", "score1", "team2", "score2"])
df.head()
# Out:
#    season team1 team2  score1  score2
# 0    2019   WAS   CON      89      78
# 1    2019   CON   WAS      78      89
# 2    2019   WAS   CON      86      90
# 3    2019   CON   WAS      90      86
# 4    2019   WAS   CON      94      81

# %% [markdown]
# **<br>Telling pandas to use YYYY-DD-MM instead of YYYY-MM-DD:**

# %%
df = pd.read_csv("wnba-team-elo-ratings.csv", index_col="date", parse_dates=True, dayfirst=True)
df.head()
# Out:
#             season team1 team2               name1               name2  \
# date
# 10/10/2019    2019   WAS   CON  Washington Mystics     Connecticut Sun
# 10/10/2019    2019   CON   WAS     Connecticut Sun  Washington Mystics
# 10/8/2019     2019   WAS   CON  Washington Mystics     Connecticut Sun
# 10/8/2019     2019   CON   WAS     Connecticut Sun  Washington Mystics
# 10/6/2019     2019   WAS   CON  Washington Mystics     Connecticut Sun
#
#             neutral  playoff  score1  score2  elo1_pre  elo2_pre  elo1_post  \
# date
# 10/10/2019        0        1      89      78      1684      1634       1692
# 10/10/2019        0        1      78      89      1634      1684       1627
# 10/8/2019         0        1      86      90      1693      1626       1684
# 10/8/2019         0        1      90      86      1626      1693       1634
# 10/6/2019         0        1      94      81      1671      1648       1693
#
#             elo2_post  prob1  is_home1
# date
# 10/10/2019       1627  0.718         1
# 10/10/2019       1692  0.282         0
# 10/8/2019        1634  0.476         0
# 10/8/2019        1684  0.524         1
# 10/6/2019        1626  0.399         0

# %% [markdown]
# <br>And many more tricks: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
